# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('sales_data.csv')
df.head()
# Out:
#    OrderID        Date Customer     Category    Sales  Quantity       City
# 0     1001  2026-04-01     Arun  Electronics  15000.0         2    Chennai
# 1     1002  2026-04-02     Bala    Furniture   8000.0         1  Bangalore
# 2     1003  2026-04-03   Charan  Electronics      NaN         1  Hyderabad
# 3     1004  2026-04-03    Divya     Clothing   2500.0         3    Chennai
# 4     1005  2026-04-04     Elan    Furniture   7000.0         2     Mumbai

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   OrderID   20 non-null     int64
#  1   Date      20 non-null     object
#  2   Customer  20 non-null     object
#  3   Category  20 non-null     object
#  4   Sales     16 non-null     float64
#  5   Quantity  20 non-null     int64
#  6   City      20 non-null     object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 1.2+ KB

# %%
df.isnull().sum()
# Out:
# OrderID     0
# Date        0
# Customer    0
# Category    0
# Sales       4
# Quantity    0
# City        0
# dtype: int64

# %%
df = df.dropna()

# %%
df = df.drop_duplicates()

# %%
df.columns = df.columns.str.strip().str.lower()
df.head()
# Out:
#    orderid        date customer     category    sales  quantity       city
# 0     1001  2026-04-01     Arun  Electronics  15000.0         2    Chennai
# 1     1002  2026-04-02     Bala    Furniture   8000.0         1  Bangalore
# 3     1004  2026-04-03    Divya     Clothing   2500.0         3    Chennai
# 4     1005  2026-04-04     Elan    Furniture   7000.0         2     Mumbai
# 5     1006  2026-04-05    Farah  Electronics  12000.0         1      Delhi

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.groupby('category')['sales'].sum()
# Out:
# category
# Clothing        11400.0
# Electronics    102000.0
# Furniture       39700.0
# Name: sales, dtype: float64

# %%
df.describe()
# Out:
#            orderid                 date         sales   quantity
# count    15.000000                   15     15.000000  15.000000
# mean   1010.133333  2026-04-08 14:24:00  10206.666667   1.933333
# min    1001.000000  2026-04-01 00:00:00   2500.000000   1.000000
# 25%    1005.500000  2026-04-04 12:00:00   5050.000000   1.000000
# 50%    1010.000000  2026-04-08 00:00:00   8200.000000   2.000000
# 75%    1014.500000  2026-04-12 12:00:00  15000.000000   2.500000
# max    1019.000000  2026-04-17 00:00:00  22000.000000   4.000000
# std       5.804760                  NaN   6489.273200   0.961150

# %%
import os

os.makedirs('../output', exist_ok=True)
df.to_csv('../output/cleaned_data.csv', index=False)

# %%
df.head()
# Out:
#    orderid       date customer     category    sales  quantity       city
# 0     1001 2026-04-01     Arun  Electronics  15000.0         2    Chennai
# 1     1002 2026-04-02     Bala    Furniture   8000.0         1  Bangalore
# 3     1004 2026-04-03    Divya     Clothing   2500.0         3    Chennai
# 4     1005 2026-04-04     Elan    Furniture   7000.0         2     Mumbai
# 5     1006 2026-04-05    Farah  Electronics  12000.0         1      Delhi

# %%
df.isnull().sum()
# Out:
# orderid     0
# date        0
# customer    0
# category    0
# sales       0
# quantity    0
# city        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.groupby('category')['sales'].sum()
# Out:
# category
# Clothing        11400.0
# Electronics    102000.0
# Furniture       39700.0
# Name: sales, dtype: float64

# %%
df.groupby('city')['sales'].sum()
# Out:
# city
# Bangalore    11000.0
# Chennai      50500.0
# Delhi        17900.0
# Hyderabad    42000.0
# Mumbai       15200.0
# Pune         16500.0
# Name: sales, dtype: float64

# %%
import matplotlib.pyplot as plt

df.groupby('category')['sales'].sum().plot(kind='bar')
plt.title('Sales by Category')
plt.xlabel('Category')
plt.ylabel('Total Sales')
plt.show()

# %%
import os

os.makedirs('../output', exist_ok=True)
df.to_csv('../output/cleaned_data.csv', index=False)

# %%
print("Data Cleaning and Reporting Completed Successfully!")
# Out:
# Data Cleaning and Reporting Completed Successfully!

# %% [markdown]
# # Data Cleaning & Reporting Automation
# This project demonstrates cleaning, preprocessing, and reporting using Python.
